# %% [markdown]
# **Candidate Elimination**

# %%
import numpy as np
import pandas as pd

dataset=pd.read_csv('candidate.csv')
print(dataset)
# Out:
#      Eyes      Nose    Head  Fcolor Hair Smile
# 0   Round  Triangle   Round  Purple  Yes   Yes
# 1  Square    Square  Square   Green  Yes    No
# 2  Square  Triangle   Round  Yellow  Yes   Yes
# 3   Round  Triangle   Round   Green   No    No
# 4  Square    Square   Round  Yellow  Yes   Yes

# %%
instance=dataset.iloc[:,:-1].values
target=dataset.iloc[:,-1].values
print("The sample data are ")
print(instance)
print("The target concept is ")
print(target)
# Out:
# The sample data are
# [['Round' 'Triangle' 'Round' 'Purple' 'Yes']
#  ['Square' 'Square' 'Square' 'Green' 'Yes']
#  ['Square' 'Triangle' 'Round' 'Yellow' 'Yes']
#  ['Round' 'Triangle' 'Round' 'Green' 'No']
#  ['Square' 'Square' 'Round' 'Yellow' 'Yes']]
# The target concept is
# ['Yes' 'No' 'Yes' 'No' 'Yes']

# %%
def learn(concepts, target): 
    specific_h = concepts[0].copy()
    print("\nInitialization of specific_h and genearal_h")
    print("\nSpecific Boundary: ", specific_h)
    general_h = [["?" for i in range(len(specific_h))] for i in range(len(specific_h))]
    print("\nGeneric Boundary: ",general_h)  

    for i, h in enumerate(concepts):
        print("\nInstance", i+1 , "is ", h)
        if target[i] == "yes":
            print("Instance is Positive ")
            for x in range(len(specific_h)): 
                if h[x]!= specific_h[x]:                    
                    specific_h[x] ='?'                     
                    general_h[x][x] ='?'
                   
        if target[i] == "no":            
            print("Instance is Negative ")
            for x in range(len(specific_h)): 
                if h[x]!= specific_h[x]:                    
                    general_h[x][x] = specific_h[x]                
                else:                    
                    general_h[x][x] = '?'        
        
        print("Specific Bundary after ", i+1, "Instance is ", specific_h)         
        print("Generic Boundary after ", i+1, "Instance is ", general_h)
        print("\n")

    indices = [i for i, val in enumerate(general_h) if val == ['?', '?', '?', '?', '?', '?']]    
    for i in indices:   
        general_h.remove(['?', '?', '?', '?', '?', '?']) 
    return specific_h, general_h 
    
s_final, g_final = learn(instance, target)
# Out:
# Initialization of specific_h and genearal_h
#
# Specific Boundary:  ['Round' 'Triangle' 'Round' 'Purple' 'Yes']
#
# Generic Boundary:  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
# Instance 1 is  ['Round' 'Triangle' 'Round' 'Purple' 'Yes']
# Specific Bundary after  1 Instance is  ['Round' 'Triangle' 'Round' 'Purple' 'Yes']
# Generic Boundary after  1 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 2 is  ['Square' 'Square' 'Square' 'Green' 'Yes']
# Specific Bundary after  2 Instance is  ['Round' 'Triangle' 'Round' 'Purple' 'Yes']
# Generic Boundary after  2 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 3 is  ['Square' 'Triangle' 'Round' 'Yellow' 'Yes']
# Specific Bundary after  3 Instance is  ['Round' 'Triangle' 'Round' 'Purple' 'Yes']
# Generic Boundary after  3 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 4 is  ['Round' 'Triangle' 'Round' 'Green' 'No']
# Specific Bundary after  4 Instance is  ['Round' 'Triangle' 'Round' 'Purple' 'Yes']
# Generic Boundary after  4 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 5 is  ['Square' 'Square' 'Round' 'Yellow' 'Yes']
# Specific Bundary after  5 Instance is  ['Round' 'Triangle' 'Round' 'Purple' 'Yes']
# Generic Boundary after  5 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]

# %%
print("Final Specific_h: ", s_final, sep="\n")
print("Final General_h: ", g_final, sep="\n")
# Out:
# Final Specific_h:
# ['Round' 'Triangle' 'Round' 'Purple' 'Yes']
# Final General_h:
# [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
